# %%
import pandas as pd

# %%
data = pd.read_csv("count&sims.csv")
data
# Out:
#      Unnamed: 0   행복  행복count    행복sims   열정  열정count    열정sims  두려움  \
# 0             0   긍정        7  0.300515   목표        9  0.154015  두려움
# 1             1   생각        7  0.362115   시간        9  0.165702   되다
# 2             2   경험        6  0.359053   열정        8  1.000000   치료
# 3             3   사람        3  0.340177   생각        8  0.278862   박사
# 4             4   기쁨        3  0.649378   상태        8  0.016050    말
# ..          ...  ...      ...       ...  ...      ...       ...  ...
# 287         287  NaN        0  0.000000   만끽        1  0.186704  NaN
# 288         288  NaN        0  0.000000   진정        1  0.202536  NaN
# 289         289  NaN        0  0.000000   방식        1  0.115559  NaN
# 290         290  NaN        0  0.000000  NaN        0  0.000000  NaN
# 291         291  NaN        0  0.000000  NaN        0  0.000000  NaN
#
#      두려움count   두려움sims    분노  분노count    분노sims   우울  우울count    우울sims   슬픔  \
# ...

# %%
data[['행복','행복count','행복sims']][data['행복sims']>0.3]
# Out:
#      행복  행복count    행복sims
# 0    긍정        7  0.300515
# 1    생각        7  0.362115
# 2    경험        6  0.359053
# 3    사람        3  0.340177
# 4    기쁨        3  0.649378
# 5    자신        2  0.377849
# 7    노력        2  0.362458
# 13  즐거움        2  0.639649
# 14   축복        2  0.398285
# 34   노래        1  0.310284
# 38   행동        1  0.320646
# 41   감정        1  0.382146
# 48   만끽        1  0.336374
# 64   행운        1  0.521165
# 66   마음        1  0.474457
# 83   후회        1  0.411582

# %%
data[['열정','열정count','열정sims']][data['열정sims']>0.3]
# Out:
#       열정  열정count    열정sims
# 2     열정        8  1.000000
# 13     힘        4  0.411853
# 19    자신        4  0.354173
# 21    마음        4  0.470146
# 35    몰입        3  0.383249
# 41    정신        2  0.447090
# 49    욕망        2  0.635713
# 50    인생        2  0.556812
# 63    인간        2  0.359653
# 71    당신        2  0.354043
# 73    침묵        2  0.384208
# 77    노력        2  0.344706
# 83    내면        2  0.383398
# 84    웃음        2  0.503354
# 87    세상        1  0.346658
# 122   능률        1  0.304199
# 130   그것        1  0.321573
# 159   헌신        1  0.521549
# 180  이야기        1  0.331314
# 199   감각        1  0.459459
# 207   본성        1  0.452631
# 220   질문        1  0.301687
# 244   기분        1  0.403035
# 259   용기        1  0.310875
# 268  외로움        1  0.523837
# 269   슬픔        1  0.610848
# 270   아픔        1  0.504940
# 273   진심        1  0.391418

# %%
data[['두려움','두려움count','두려움sims']][data['두려움sims']>0.3]
# Out:
#      두려움  두려움count   두려움sims
# 0    두려움        12  1.000000
# 5     사람         4  0.386792
# 6     공포         4  0.437150
# 7     감정         4  0.603039
# 14    자신         3  0.401552
# 16    생각         3  0.344774
# 18    위험         2  0.517086
# 19    상황         2  0.336036
# 23    경험         2  0.397709
# 27     몸         2  0.382896
# 37   스스로         2  0.301661
# 57    인간         1  0.428638
# 81    긴장         1  0.388085
# 92   무언가         1  0.320892
# 100   조언         1  0.378309
# 107  즐거움         1  0.542532
# 109   신체         1  0.308115
# 118   가슴         1  0.353419
# 138  호기심         1  0.629956
# 144   자기         1  0.324252
# 146   긍정         1  0.308657
# 169   행동         1  0.433627
# 172  공포증         1  0.492378
# 180   불안         1  0.552218
# 185   중독         1  0.324993
# 188   경고         1  0.355002

# %%
data[['분노','분노count','분노sims']][data['분노sims']>0.3]
# Out:
#       분노  분노count    분노sims
# 1     마음        9  0.458437
# 4     감정        8  0.361590
# 10    상처        5  0.416839
# 16    생각        4  0.318623
# 17    분노        3  1.000000
# 38   열등감        2  0.342865
# 44    자극        2  0.312304
# 51    반응        2  0.347097
# 77    공격        1  0.371177
# 87   오히려        1  0.386043
# 102   태도        1  0.399469
# 122  스스로        1  0.422716
# 165  수치심        1  0.383244
# 188   우울        1  0.333224
# 189  불안감        1  0.485962
# 192   반대        1  0.386900
# 213   대처        1  0.367593
# 236   온갖        1  0.304854
# 244   불안        1  0.425699
# 246   슬픔        1  0.460731

# %%
data[['우울','우울count','우울sims']][data['우울sims']>0.3]
# Out:
#        우울  우울count    우울sims
# 1     우울증       10  0.551881
# 8      극복        3  0.357742
# 16     슬픔        2  0.567988
# 20      삶        2  0.305402
# 50    무관심        1  0.459993
# 72     긍정        1  0.317473
# 77     집착        1  0.413683
# 81     불행        1  0.506694
# 94    악순환        1  0.308337
# 104    마음        1  0.393085
# 166    우울        1  1.000000
# 193  스트레스        1  0.352501
# 194    불안        1  0.535015
# 204    감정        1  0.524577
# 207    경험        1  0.332738

# %%
data[['슬픔','슬픔count','슬픔sims']][data['슬픔sims']>0.3]
# Out:
#      슬픔  슬픔count    슬픔sims
# 0    사람       12  0.372000
# 1    슬픔        7  1.000000
# 5    우리        4  0.320894
# 6    죽음        4  0.621415
# 7    감정        4  0.570532
# 10   기억        3  0.446940
# 11    삶        3  0.516323
# 13   증상        2  0.380539
# 20   고통        2  0.639488
# 23   사랑        2  0.721666
# 26   인생        2  0.598374
# 27   습관        2  0.350893
# 28   정서        1  0.317807
# 30   비탄        1  0.729768
# 32   피로        1  0.388876
# 33   식욕        1  0.436198
# 34   성욕        1  0.480976
# 37   그것        1  0.303085
# 59  이야기        1  0.412903
# 67   좌절        1  0.307993
# 81   현실        1  0.364640
# 82   항상        1  0.365796
# 90   가족        1  0.335022
# 91   친구        1  0.390999
