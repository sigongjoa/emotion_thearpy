# %%
import pandas as pd
from gensim.models import Word2Vec

# %%
model = Word2Vec.load('../ko/ko.bin')
# Out:
# C:\Users\fd\anaconda3\lib\site-packages\gensim\models\base_any2vec.py:742: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   warnings.warn(

# %%
# 1000개를 봐도 다 과학적인 내요임
model.wv.most_similar('에너지',topn=1000)
# Out:
# [('엔트로피', 0.6763189435005188),
#  ('광자', 0.6456081867218018),
#  ('플라즈마', 0.6251395344734192),
#  ('중성자', 0.6244688630104065),
#  ('전자기파', 0.6196104288101196),
#  ('이산화탄소', 0.6033062934875488),
#  ('유체', 0.6024906039237976),
#  ('물질', 0.6009037494659424),
#  ('기체', 0.5979229211807251),
#  ('산소', 0.596539318561554),
#  ('연료', 0.5889571905136108),
#  ('온도', 0.5889348983764648),
#  ('입자', 0.5885133743286133),
#  ('진동수', 0.5878738164901733),
#  ('물체', 0.58503258228302),
#  ('헬륨', 0.5723544955253601),
#  ('전자파', 0.5691305994987488),
#  ('액체', 0.5690488219261169),
#  ('이온화', 0.568343997001648),
#  ('시료', 0.5670230984687805),
#  ('수증기', 0.5661979913711548),
#  ('운동량', 0.5660855770111084),
#  ('모멘트', 0.5652351379394531),
#  ('질량', 0.56063312292099),
#  ('부피', 0.559983491897583),
#  ('중수소', 0.5595340728759766),
#  ('전류', 0.5569190979003906),
#  ('양성자', 0.5544267892837524),
#  ('가속도', 0.5515415668487549),
#  ('수소', 0.5501229166984558),
#  ('충격파', 0.5476220846176147),
# ...

# %%
model.wv.most_similar('기운',topn=1000)
# Out:
# [('생명력', 0.5765432119369507),
#  ('햇빛', 0.5637161731719971),
#  ('긴장감', 0.5436817407608032),
#  ('불길', 0.5413690209388733),
#  ('슬픔', 0.539458692073822),
#  ('물결', 0.5378740429878235),
#  ('구름', 0.5359838604927063),
#  ('숨결', 0.5334983468055725),
#  ('햇살', 0.5322412252426147),
#  ('하늘', 0.5298808813095093),
#  ('온몸', 0.5294333100318909),
#  ('기쁨', 0.5252145528793335),
#  ('저절로', 0.5156455039978027),
#  ('바람', 0.5140365362167358),
#  ('활력', 0.5131714344024658),
#  ('불안감', 0.5115952491760254),
#  ('비바람', 0.5089428424835205),
#  ('힘', 0.5080716013908386),
#  ('벼락', 0.507954478263855),
#  ('의욕', 0.5075427293777466),
#  ('복수심', 0.5033953189849854),
#  ('불꽃', 0.5011154413223267),
#  ('빛', 0.5008140206336975),
#  ('땅', 0.5006872415542603),
#  ('영혼', 0.4952627718448639),
#  ('몸', 0.4946863055229187),
#  ('흙', 0.49254775047302246),
#  ('강물', 0.49131688475608826),
#  ('근심', 0.49124032258987427),
#  ('재앙', 0.49094951152801514),
#  ('자신감', 0.4899209439754486),
#  ('씨앗', 0.4880148470401764),
# ...
